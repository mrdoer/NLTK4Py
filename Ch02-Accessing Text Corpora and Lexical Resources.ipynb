# %% [markdown]
# # 1. Accessing Text Corpora(linguistic data)

# %% [markdown]
# ## 1.1 Gutenberg Corpus

# %%
import nltk

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
emma = nltk.corpus.gutenberg.words('austen-emma.txt')

# %%
print(emma[0:100])
# Out:
# ['[', 'Emma', 'by', 'Jane', 'Austen', '1816', ']', 'VOLUME', 'I', 'CHAPTER', 'I', 'Emma', 'Woodhouse', ',', 'handsome', ',', 'clever', ',', 'and', 'rich', ',', 'with', 'a', 'comfortable', 'home', 'and', 'happy', 'disposition', ',', 'seemed', 'to', 'unite', 'some', 'of', 'the', 'best', 'blessings', 'of', 'existence', ';', 'and', 'had', 'lived', 'nearly', 'twenty', '-', 'one', 'years', 'in', 'the', 'world', 'with', 'very', 'little', 'to', 'distress', 'or', 'vex', 'her', '.', 'She', 'was', 'the', 'youngest', 'of', 'the', 'two', 'daughters', 'of', 'a', 'most', 'affectionate', ',', 'indulgent', 'father', ';', 'and', 'had', ',', 'in', 'consequence', 'of', 'her', 'sister', "'", 's', 'marriage', ',', 'been', 'mistress', 'of', 'his', 'house', 'from', 'a', 'very', 'early', 'period', '.', 'Her']

# %%
len(emma)
# Out:
# 192427

# %%
from nltk.corpus import gutenberg

# %%
gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
emma = gutenberg.words('austen-emma.txt')

# %% [markdown]
# ###  lexical diversity score
# - average word length,
# - average sentence length, and
# - the number of times each vocabulary item appears in the text on average.

# %%
for fileid in gutenberg.fileids():
    num_chars = len(gutenberg.raw(fileid))
    num_words = len(gutenberg.words(fileid))
    num_sents = len(gutenberg.sents(fileid))
    num_vocab = len(set(w.lower() for w in gutenberg.words(fileid)))
    print (round(num_chars/num_words),round(num_words/num_sents),round(num_words/num_vocab),fileid)
# Out:
# 5 25 26 austen-emma.txt
# 5 26 17 austen-persuasion.txt
# 5 28 22 austen-sense.txt
# 4 34 79 bible-kjv.txt
# 5 19 5 blake-poems.txt
# 4 19 14 bryant-stories.txt
# 4 18 12 burgess-busterbrown.txt
# 4 20 13 carroll-alice.txt
# 5 20 12 chesterton-ball.txt
# 5 23 11 chesterton-brown.txt
# 5 18 11 chesterton-thursday.txt
# 4 21 25 edgeworth-parents.txt
# 5 26 15 melville-moby_dick.txt
# 5 52 11 milton-paradise.txt
# 4 12 9 shakespeare-caesar.txt
# 4 12 8 shakespeare-hamlet.txt
# 4 12 7 shakespeare-macbeth.txt
# 5 36 12 whitman-leaves.txt

# %%
macbeth_sentences = gutenberg.sents('shakespeare-macbeth.txt')

# %%
macbeth_sentences[100]
# Out:
# ['Enter', 'Macbeth', 'and', 'Banquo', '.']

# %%
len(macbeth_sentences[99])
# Out:
# 9

# %%
len(gutenberg.fileids())
# Out:
# 18

# %% [markdown]
# ## 1.2   Web and Chat Text

# %% [markdown]
# ### - web text

# %%
from nltk.corpus import webtext

# %%
webtext.fileids()
# Out:
# ['firefox.txt',
#  'grail.txt',
#  'overheard.txt',
#  'pirates.txt',
#  'singles.txt',
#  'wine.txt']

# %%
for fileid in webtext.fileids():
    print(fileid,len(webtext.raw(fileid)))
# Out:
# firefox.txt 564601
# grail.txt 65003
# overheard.txt 830118
# pirates.txt 95368
# singles.txt 21302
# wine.txt 149772

# %% [markdown]
# ###  - chat sessions

# %%
from nltk.corpus import nps_chat

# %%
chatroom = nps_chat.posts('10-19-20s_706posts.xml')

# %%
type(chatroom)
# Out:
# nltk.corpus.reader.xmldocs.XMLCorpusView

# %%
print(chatroom[123])
# Out:
# ['i', 'do', "n't", 'want', 'hot', 'pics', 'of', 'a', 'female', ',', 'I', 'can', 'look', 'in', 'a', 'mirror', '.']

# %%
' '.join(chatroom[123])
# Out:
# "i do n't want hot pics of a female , I can look in a mirror ."

# %% [markdown]
# ## 1.3 Brown Corpus

# %%
from nltk.corpus import brown
brown.categories()
# Out:
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %%
brown.words(categories='humor')
# Out:
# ['It', 'was', 'among', 'these', 'that', 'Hinkle', ...]

# %% [markdown]
# ## 1.4   Reuters Corpus

# %%
from nltk.corpus import reuters

# %%
reuters.fileids()
# Out:
# ['test/14826',
#  'test/14828',
#  'test/14829',
#  'test/14832',
#  'test/14833',
#  'test/14839',
#  'test/14840',
#  'test/14841',
#  'test/14842',
#  'test/14843',
#  'test/14844',
#  'test/14849',
#  'test/14852',
#  'test/14854',
#  'test/14858',
#  'test/14859',
#  'test/14860',
#  'test/14861',
#  'test/14862',
#  'test/14863',
#  'test/14865',
#  'test/14867',
#  'test/14872',
#  'test/14873',
#  'test/14875',
#  'test/14876',
#  'test/14877',
#  'test/14881',
#  'test/14882',
#  'test/14885',
#  'test/14886',
#  'test/14888',
#  'test/14890',
#  'test/14891',
#  'test/14892',
#  'test/14899',
#  'test/14900',
#  'test/14903',
#  'test/14904',
#  'test/14907',
#  'test/14909',
#  'test/14911',
#  'test/14912',
#  'test/14913',
#  'test/14918',
#  'test/14919',
#  'test/14921',
#  'test/14922',
#  'test/14923',
#  'test/14926',
#  'test/14928',
#  'test/14930',
#  'test/14931',
#  'test/14932',
#  'test/14933',
#  'test/14934',
#  'test/14941',
#  'test/14943',
# ...

# %%
reuters.categories()
# Out:
# ['acq',
#  'alum',
#  'barley',
#  'bop',
#  'carcass',
#  'castor-oil',
#  'cocoa',
#  'coconut',
#  'coconut-oil',
#  'coffee',
#  'copper',
#  'copra-cake',
#  'corn',
#  'cotton',
#  'cotton-oil',
#  'cpi',
#  'cpu',
#  'crude',
#  'dfl',
#  'dlr',
#  'dmk',
#  'earn',
#  'fuel',
#  'gas',
#  'gnp',
#  'gold',
#  'grain',
#  'groundnut',
#  'groundnut-oil',
#  'heat',
#  'hog',
#  'housing',
#  'income',
#  'instal-debt',
#  'interest',
#  'ipi',
#  'iron-steel',
#  'jet',
#  'jobs',
#  'l-cattle',
#  'lead',
#  'lei',
#  'lin-oil',
#  'livestock',
#  'lumber',
#  'meal-feed',
#  'money-fx',
#  'money-supply',
#  'naphtha',
#  'nat-gas',
#  'nickel',
#  'nkr',
#  'nzdlr',
#  'oat',
#  'oilseed',
#  'orange',
#  'palladium',
#  'palm-oil',
#  'palmkernel',
#  'pet-chem',
#  'platinum',
#  'potato',
#  'propane',
#  'rand',
#  'rape-oil',
#  'rapeseed',
#  'reserves',
#  'retail',
#  'rice',
#  'rubber',
#  'rye',
#  'ship',
#  'silver',
#  'sorghum',
#  'soy-meal',
#  'soy-oil',
# ...

# %% [markdown]
# ## 1.5 Inaugural Address Corpus

# %%
from nltk.corpus import inaugural

# %%
inaugural.fileids()
# Out:
# ['1789-Washington.txt',
#  '1793-Washington.txt',
#  '1797-Adams.txt',
#  '1801-Jefferson.txt',
#  '1805-Jefferson.txt',
#  '1809-Madison.txt',
#  '1813-Madison.txt',
#  '1817-Monroe.txt',
#  '1821-Monroe.txt',
#  '1825-Adams.txt',
#  '1829-Jackson.txt',
#  '1833-Jackson.txt',
#  '1837-VanBuren.txt',
#  '1841-Harrison.txt',
#  '1845-Polk.txt',
#  '1849-Taylor.txt',
#  '1853-Pierce.txt',
#  '1857-Buchanan.txt',
#  '1861-Lincoln.txt',
#  '1865-Lincoln.txt',
#  '1869-Grant.txt',
#  '1873-Grant.txt',
#  '1877-Hayes.txt',
#  '1881-Garfield.txt',
#  '1885-Cleveland.txt',
#  '1889-Harrison.txt',
#  '1893-Cleveland.txt',
#  '1897-McKinley.txt',
#  '1901-McKinley.txt',
#  '1905-Roosevelt.txt',
#  '1909-Taft.txt',
#  '1913-Wilson.txt',
#  '1917-Wilson.txt',
#  '1921-Harding.txt',
#  '1925-Coolidge.txt',
#  '1929-Hoover.txt',
#  '1933-Roosevelt.txt',
#  '1937-Roosevelt.txt',
#  '1941-Roosevelt.txt',
#  '1945-Roosevelt.txt',
#  '1949-Truman.txt',
#  '1953-Eisenhower.txt',
# ...

# %%
cfd = nltk.ConditionalFreqDist(
           (target, fileid[:4])
           for fileid in inaugural.fileids()
           for w in inaugural.words(fileid)
           for target in ['america', 'citizen']
           if w.lower().startswith(target))

# %%
cfd.plot()

# %% [markdown]
# ## 1.6   Annotated Text Corpora

# %% [markdown]
# ## 1.7   Corpora in Other Languages

# %%
from nltk.corpus import udhr

# %%
languages = ['Chickasaw', 'English', 'German_Deutsch',
     'Greenlandic_Inuktikut', 'Hungarian_Magyar', 'Ibibio_Efik']

# %%
cfd = nltk.ConditionalFreqDist(
           (lang, len(word))
           for lang in languages
           for word in udhr.words(lang + '-Latin1'))
cfd.plot(cumulative = True)

# %%
udhr.fileids()
# Out:
# ['Abkhaz-Cyrillic+Abkh',
#  'Abkhaz-UTF8',
#  'Achehnese-Latin1',
#  'Achuar-Shiwiar-Latin1',
#  'Adja-UTF8',
#  'Afaan_Oromo_Oromiffa-Latin1',
#  'Afrikaans-Latin1',
#  'Aguaruna-Latin1',
#  'Akuapem_Twi-UTF8',
#  'Albanian_Shqip-Latin1',
#  'Amahuaca',
#  'Amahuaca-Latin1',
#  'Amarakaeri-Latin1',
#  'Amuesha-Yanesha-UTF8',
#  'Arabela-Latin1',
#  'Arabic_Alarabia-Arabic',
#  'Asante-UTF8',
#  'Ashaninca-Latin1',
#  'Asheninca-Latin1',
#  'Asturian_Bable-Latin1',
#  'Aymara-Latin1',
#  'Balinese-Latin1',
#  'Bambara-UTF8',
#  'Baoule-UTF8',
#  'Basque_Euskara-Latin1',
#  'Batonu_Bariba-UTF8',
#  'Belorus_Belaruski-Cyrillic',
#  'Belorus_Belaruski-UTF8',
#  'Bemba-Latin1',
#  'Bengali-UTF8',
#  'Beti-UTF8',
#  'Bichelamar-Latin1',
#  'Bikol_Bicolano-Latin1',
#  'Bora-Latin1',
#  'Bosnian_Bosanski-Cyrillic',
#  'Bosnian_Bosanski-Latin2',
#  'Bosnian_Bosanski-UTF8',
#  'Breton-Latin1',
#  'Bugisnese-Latin1',
#  'Bulgarian_Balgarski-Cyrillic',
#  'Bulgarian_Balgarski-UTF8',
# ...

# %%
udhr_cn = udhr.words('Chinese_Mandarin-GB2312')

# %%
nltk.corpus.reuters.readme()
# Out:
# '\n      The Reuters-21578 benchmark corpus, ApteMod version\n\nThis is a publically available version of the well-known Reuters-21578\n"ApteMod" corpus for text categorization.  It has been used in\npublications like these:\n\n * Yiming Yang and X. Liu. "A re-examination of text categorization\n   methods".  1999.  Proceedings of 22nd Annual International SIGIR.\n   http://citeseer.nj.nec.com/yang99reexamination.html\n\n * Thorsten Joachims. "Text categorization with support vector\n   machines: learning with many relevant features".  1998. Proceedings\n   of ECML-98, 10th European Conference on Machine Learning.\n   http://citeseer.nj.nec.com/joachims98text.html\n\nApteMod is a collection of 10,788 documents from the Reuters financial\nnewswire service, partitioned into a training set with 7769 documents\nand a test set with 3019 documents.  The total size of the corpus is\nabout 43 MB.  It is also available for download from\nhttp://kdd.ics.uci.edu/databases/reuters21578/reuters21
# ...

# %% [markdown]
# ## 1.8   Text Corpus Structure

# %% [markdown]
# Example | Description
#
#
# fileids() | the files of the corpus
# fileids([categories]) the files of the corpus corresponding to these categories
# categories() the categories of the corpus
# categories([fileids]) the categories of the corpus corresponding to these files
# raw() the raw content of the corpus
# raw(fileids=[f1,f2,f3]) the raw content of the specified files
# raw(categories=[c1,c2]) the raw content of the specified categories
# words() the words of the whole corpus
# words(fileids=[f1,f2,f3]) the words of the specified fileids
# words(categories=[c1,c2]) the words of the specified categories
# sents() the sentences of the whole corpus
# sents(fileids=[f1,f2,f3]) the sentences of the specified fileids
# sents(categories=[c1,c2]) the sentences of the specified categories
# abspath(fileid) the location of the given file on disk
# encoding(fileid) the encoding of the file (if known)
# open(fileid) open a stream for reading the given corpus file
# root if the path to the root of locally installed corpus
# readme() the contents of the README file of the corpus

# %% [markdown]
# ## 1.9   Loading your own Corpus

# %%
from nltk.corpus import PlaintextCorpusReader

# %%
corpus_root = 'C:/Users/EIEUCHH/Documents/Trace/'

# %%
wordlists  = PlaintextCorpusReader(corpus_root,'.*')

# %%
wordlists.fileids()
# Out:
# ['Book01.txt', 'News01.txt', 'Trace_sample.txt']

# %%
trace = wordlists.words('News01.txt')

# %%
trace
# Out:
# ['According', 'to', 'a', 'Downing', 'Street', ...]

# %%
len(trace)
# Out:
# 399

# %%
trace_sents = wordlists.sents('News01.txt')

# %%
len(trace_sents)
# Out:
# 15

# %%
len(wordlists.raw('News01.txt'))
# Out:
# 2078

# %%
len(wordlists.words('News01.txt'))
# Out:
# 399

# %%
len(wordlists.fileids())
# Out:
# 3

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text1.concordance('he')
# Out:
# Displaying 25 of 25 matches:
# t , body , and brain ; I see him now . He was ever dusting his old lexicons and
# f all the known nations of the world . He loved to dust his old grammars ; it so
# up whatever random allusions to whales he could anyways find in any book whatsoe
# n Leviathan that crooked serpent ; and he shall slay the dragon that is in the s
# E ' S LUCIAN . " THE TRUE HISTORY ." " He visited this country also with a view
# great value for their teeth , of which he brought some to the king . ... The bes
# orty - eight , some fifty yards long . He said that he was one of six who had ki
# , some fifty yards long . He said that he was one of six who had killed sixty in
# pencer ' s Talus with his modern flail He threatens ruin with his ponderous tail
# ... Their fixed jav ' lins in his side he wears , And on his back a grove of pik
# .. One of our harpooneers told me that he caught once a whale in Spitzbergen tha
# ...

# %%
trace.count('is')
# Out:
# 7

# %%
import string

# %%
for w in set(trace):
    if w not in string.punctuation:
        print (w,trace.count(w))
# Out:
# notable 1
# Mexico 2
# m 1
# worldwide 1
# continued 1
# an 1
# jobs 1
# had 1
# spokesperson 1
# as 2
# tell 1
# you 1
# decision 5
# affected 1
# his 1
# agreement 1
# case 1
# points 1
# further 1
# unbalance 1
# through 2
# leader 1
# fail 1
# underscored 1
# by 2
# only 1
# direct 2
# unilateral 1
# at 1
# to 12
# press 1
# disappointing 1
# of 5
# readout 1
# fragmentations 1
# in 4
# Downing 1
# Prime 3
# strained 1
# ahead 1
# a 8
# ," 4
# mistake 2
# This 1
# same 1
# the 29
# prefer 1
# say 1
# she 1
# arguably 1
# two 1
# manage 1
# Sometimes 1
# also 1
# According 1
# across 1
# ." 4
# been 1
# said 8
# convince 1
# whom 1
# values 1
# was 1
# closest 1
# national 1
# day 2
# States 1
# trade 2
# knows 1
# discussed 1
# UK 1
# Paris 1
# apply 1
# came 1
# deeply 1
# are 2
# because 3
# Thursday 1
# allies 3
# Elysee 1
# It 1
# He 1
# House 1
# exists 1
# Europe 1
# other 1
# The 4
# imports 1
# tariffs 4
# fair 1
# world 1
# things 2
# European 3
# has 1
# American 2
# ...

# %%
fdist = FreqDist(trace)

# %%
fdist
# Out:
# FreqDist({'the': 29, ',': 18, 'and': 14, 'to': 12, '.': 11, '"': 10, 'a': 8, 'said': 8, 'is': 7, 'Macron': 6, ...})

# %%
fdist.most_common(20)
# Out:
# [('the', 29),
#  (',', 18),
#  ('and', 14),
#  ('to', 12),
#  ('.', 11),
#  ('"', 10),
#  ('a', 8),
#  ('said', 8),
#  ('is', 7),
#  ('Macron', 6),
#  ('I', 6),
#  ('decision', 5),
#  ('of', 5),
#  ('with', 5),
#  ('he', 5),
#  ('tariffs', 4),
#  ('The', 4),
#  ('US', 4),
#  (',"', 4),
#  ('statement', 4)]

# %%
trace.unicode_repr
# Out:
# <bound method AbstractLazySequence.__repr__ of ['According', 'to', 'a', 'Downing', 'Street', ...]>

# %% [markdown]
# # 2.   Conditional Frequency Distributions

# %% [markdown]
# ### - count by genre

# %%
from nltk.corpus import brown

# %%
cfd = nltk.ConditionalFreqDist(
            (genre, word)
            for genre in brown.categories()
            for word in brown.words(categories=genre))

# %%
#from nltk.corpus import brown
cfd_ = nltk.ConditionalFreqDist(
            (genre, word)
            for genre in ['news','romance','humor']
            for word in brown.words(categories=genre))
#cfd_.plot()

# %%
cfd_.conditions()
# Out:
# ['news', 'romance', 'humor']

# %%
print(cfd_['news'])
# Out:
# <FreqDist with 14394 samples and 100554 outcomes>

# %%
print(cfd_['news'].most_common(20))
# Out:
# [('the', 5580), (',', 5188), ('.', 4030), ('of', 2849), ('and', 2146), ('to', 2116), ('a', 1993), ('in', 1893), ('for', 943), ('The', 806), ('that', 802), ('``', 732), ('is', 732), ('was', 717), ("''", 702), ('on', 657), ('at', 598), ('with', 545), ('be', 526), ('by', 497)]

# %%
text_news = cfd_['news']

# %%
text_news.freq('the')
# Out:
# 0.05549257115579689

# %%
text_news.elements()

# %%
text_news.max()
# Out:
# 'the'

# %% [markdown]
# ## 2.4   Generating Random Text with Bigrams

# %%
sent = ['In','the','begining','God','create','the','heaven','and','the','earth','.']

# %%
' '.join(sent)
# Out:
# 'In the begining God create the heaven and the earth .'

# %%
list(nltk.bigrams(sent))
# Out:
# [('In', 'the'),
#  ('the', 'begining'),
#  ('begining', 'God'),
#  ('God', 'create'),
#  ('create', 'the'),
#  ('the', 'heaven'),
#  ('heaven', 'and'),
#  ('and', 'the'),
#  ('the', 'earth'),
#  ('earth', '.')]

# %%
def generate_model (cfdist, word, num = 15 ):
    for i in range(num):
        print(word,end = ' ')
        word = cfdist[word].max()
        
text = nltk.corpus.genesis.words('english-kjv.txt')
bigrams = nltk.bigrams(text)
cfd = nltk.ConditionalFreqDist(bigrams)

# %%
cfd['living']
# Out:
# FreqDist({'creature': 7, 'thing': 4, 'substance': 2, 'soul': 1, '.': 1, ',': 1})

# %%
cfd['creature']
# Out:
# FreqDist({'that': 4, 'of': 2, 'after': 1, ',': 1})

# %%
cfd['he']
# Out:
# FreqDist({'said': 115, 'had': 49, 'was': 23, 'begat': 18, 'took': 17, 'called': 15, 'shall': 14, 'hath': 13, 'is': 13, 'made': 11, ...})

# %%
cfd['said']
# Out:
# FreqDist({',': 259, 'unto': 178, 'to': 20, 'in': 3, 'one': 3, '.': 2, 'he': 2, 'thus': 2, 'she': 1, 'again': 1, ...})

# %%
cfd[',']
# Out:
# FreqDist({'and': 1491, 'I': 145, 'that': 130, 'which': 92, 'the': 79, 'saying': 77, 'behold': 55, 'when': 46, 'Behold': 43, 'as': 37, ...})

# %%
cfd['thing']
# Out:
# FreqDist({'that': 14, ',': 7, 'which': 3, 'of': 2, 'was': 2, 'living': 1, 'too': 1, 'also': 1, '?': 1, ';': 1, ...})

# %%
generate_model(cfd,'living')
# Out:
# living creature that he said , and the land of the land of the land

# %% [markdown]
# # 3   More Python: Reusing Code

# %% [markdown]
# # 4   Lexical Resources

# %% [markdown]
# ## 4.1   Wordlist Corpora

# %%
text_path = 'C:/Users/EIEUCHH/Documents/Trace/'

# %%
wordlist = PlaintextCorpusReader(text_path,'.*')

# %%
wordlist.fileids()
# Out:
# ['Book01.txt', 'News01.txt', 'Trace_sample.txt']

# %%
news_txt = wordlist.words('News01.txt')

# %%
print(news_txt)
# Out:
# ['According', 'to', 'a', 'Downing', 'Street', ...]

# %%
def unusual_words (text):
    text_vocab = set(w.lower() for w in text if w.isalpha())
    english_vocab = set(w.lower() for w in nltk.corpus.words.words())
    unusual = text_vocab - english_vocab
    return set(unusual)

# %%
unusual_words(news_txt)
# Out:
# {'adding',
#  'announced',
#  'arguably',
#  'bbc',
#  'closest',
#  'convictions',
#  'discussed',
#  'europe',
#  'exists',
#  'fragmentations',
#  'has',
#  'imports',
#  'including',
#  'issued',
#  'jobs',
#  'knows',
#  'matters',
#  'mexico',
#  'points',
#  'readout',
#  'recognise',
#  'regrets',
#  'relations',
#  'responds',
#  'spokesperson',
#  'states',
#  'tariffs',
#  'things',
#  'uk',
#  'underlined',
#  'underscored',
#  'values',
#  'worldwide'}

# %%
from code_unusual import *
import nltk

# %%
unusual_words(news_txt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-119-444fa788eca3> in <module>()
# ----> 1 unusual_words(news_txt)
#
# ~\Documents\PyScriptChen\NLTK4Py\code_unusual.py in unusual_words(text)
#       1 import nltk
#       2 def unusual_words (text):
# ----> 3         text_vocab = set(w.lower() for w in text if w.isalpha())
#       4         english_vocab = set(w.lower() for w in nltk.corpus.words.words())
#       5         unusual = text_vocab - english_vocab
#
# NameError: name 'nltk' is not defined

# %%
import print_sumab
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-126-998d125e58f9> in <module>()
# ----> 1 from print_sumab.print_sum import print_sum
#
# ModuleNotFoundError: No module named 'print_sumab.print_sum'; 'print_sumab' is not a package

# %%
print_sumab.print_sum(1,2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-125-c6479976305b> in <module>()
# ----> 1 print_sumab.print_sum(1,2)
#
# ~\Documents\PyScriptChen\NLTK4Py\print_sumab.py in print_sum(a, b)
#       1 import add_ab from add_num
#       2 def print_sum (a,b):
# ----> 3         print (add_ab(a,b))
#
# NameError: name 'add_ab' is not defined

# %% [markdown]
# #### cfd name

# %%
import nltk

# %%
names = nltk.corpus.names

# %%
names.fileids()
# Out:
# ['female.txt', 'male.txt']

# %%
male_names = names.words('male.txt')

# %%
female_names = names.words('female.txt')

# %%
cfd_name = nltk.ConditionalFreqDist(
    (fileid, name[-1])
    for fileid in names.fileids()
    for name in names.words(fileid))

# %%
cfd_name.plot()

# %% [markdown]
# ## 4.2   A Pronouncing Dictionary

# %% [markdown]
# ## 4.3 Comparative Wordlists

# %%
from nltk.corpus import swadesh

# %%
swadesh.fileids()
# Out:
# ['be',
#  'bg',
#  'bs',
#  'ca',
#  'cs',
#  'cu',
#  'de',
#  'en',
#  'es',
#  'fr',
#  'hr',
#  'it',
#  'la',
#  'mk',
#  'nl',
#  'pl',
#  'pt',
#  'ro',
#  'ru',
#  'sk',
#  'sl',
#  'sr',
#  'sw',
#  'uk']

# %%
swadesh.words('en')
# Out:
# ['I',
#  'you (singular), thou',
#  'he',
#  'we',
#  'you (plural)',
#  'they',
#  'this',
#  'that',
#  'here',
#  'there',
#  'who',
#  'what',
#  'where',
#  'when',
#  'how',
#  'not',
#  'all',
#  'many',
#  'some',
#  'few',
#  'other',
#  'one',
#  'two',
#  'three',
#  'four',
#  'five',
#  'big',
#  'long',
#  'wide',
#  'thick',
#  'heavy',
#  'small',
#  'short',
#  'narrow',
#  'thin',
#  'woman',
#  'man (adult male)',
#  'man (human being)',
#  'child',
#  'wife',
#  'husband',
#  'mother',
#  'father',
#  'animal',
#  'fish',
#  'bird',
#  'dog',
#  'louse',
#  'snake',
#  'worm',
#  'tree',
#  'forest',
#  'stick',
#  'fruit',
#  'seed',
#  'leaf',
#  'root',
#  'bark (from tree)',
#  'flower',
#  'grass',
#  'rope',
#  'skin',
#  'meat',
#  'blood',
#  'bone',
#  'fat (noun)',
#  'egg',
#  'horn',
#  'tail',
#  'feather',
#  'hair',
#  'head',
#  'ear',
#  'eye',
#  'nose',
#  'mouth',
#  'tooth',
#  'tongue',
#  'fingernail',
#  'foot',
#  'leg',
#  'knee',
# ...

# %%
swadesh.words('uk')
# Out:
# ['я',
#  'ти',
#  'він',
#  'ми',
#  'ви',
#  'вони',
#  'це',
#  'те',
#  'тут',
#  'там',
#  'хто',
#  'що',
#  'де',
#  'коли',
#  'як',
#  'не',
#  'усі',
#  'багато',
#  'кілька',
#  'небагато',
#  'інший',
#  'один',
#  'два',
#  'три',
#  'чотири',
#  "п'ять",
#  'великий',
#  'довгий',
#  'широкий',
#  'товстий',
#  'важкий',
#  'маленький',
#  'короткий',
#  'вузький',
#  'тонкий',
#  'жінка',
#  'чоловік',
#  'людина',
#  'дитя',
#  'жінка',
#  'чоловік',
#  'мати',
#  'батько',
#  'тварина',
#  'риба',
#  'птах',
#  'пес',
#  'воша',
#  'змія',
#  'хробак',
#  'дерево',
#  'ліс',
#  'палиця',
#  'фрукт',
#  'насіння',
#  'листок',
#  'корінь',
#  'кора',
#  'квітка',
#  'трава',
#  'мотузка',
#  'шкіра',
#  "м'ясо",
#  'кров',
#  'кістка',
#  'сало',
#  'яйце',
#  'ріг',
#  'хвіст',
#  'перо',
#  'волосся',
#  'голова',
#  'вухо',
#  'око',
#  'ніс',
#  'рот',
#  'зуб',
#  'язик',
#  'ніготь',
#  'стопа',
#  'нога',
#  'коліно',
#  'рука',
#  'крило',
#  'живіт',
# ...

# %%
fr2en = swadesh.entries(['de','en'])

# %%
fr2en
# Out:
# [('ich', 'I'),
#  ('du, Sie', 'you (singular), thou'),
#  ('er', 'he'),
#  ('wir', 'we'),
#  ('ihr, Sie', 'you (plural)'),
#  ('sie', 'they'),
#  ('dieses', 'this'),
#  ('jenes', 'that'),
#  ('hier', 'here'),
#  ('dort', 'there'),
#  ('wer', 'who'),
#  ('was', 'what'),
#  ('wo', 'where'),
#  ('wann', 'when'),
#  ('wie', 'how'),
#  ('nicht', 'not'),
#  ('alle', 'all'),
#  ('viele', 'many'),
#  ('einige', 'some'),
#  ('wenige', 'few'),
#  ('andere', 'other'),
#  ('eins', 'one'),
#  ('zwei', 'two'),
#  ('drei', 'three'),
#  ('vier', 'four'),
#  ('fünf', 'five'),
#  ('groß', 'big'),
#  ('lang', 'long'),
#  ('breit, weit', 'wide'),
#  ('dick', 'thick'),
#  ('schwer', 'heavy'),
#  ('klein', 'small'),
#  ('kurz', 'short'),
#  ('eng', 'narrow'),
#  ('dünn', 'thin'),
#  ('Frau', 'woman'),
#  ('Mann', 'man (adult male)'),
#  ('Mensch', 'man (human being)'),
#  ('Kind', 'child'),
#  ('Frau, Ehefrau', 'wife'),
#  ('Mann, Ehemann', 'husband'),
#  ('Mutter', 'mother'),
#  ('Vater', 'father'),
# ...

# %%
translate = dict(fr2en)

# %%
translate['ich']
# Out:
# 'I'

# %% [markdown]
# ## 4.4 Shoeboc and ToolBox Lexicons

# %%
unusual_words(nltk.corpus.gutenberg.words('austen-sense.txt'))
# Out:
# {'hears',
#  'contributed',
#  'ensured',
#  'endeavours',
#  'children',
#  'intends',
#  'whitakers',
#  'hardships',
#  'contrasted',
#  'meadows',
#  'beasts',
#  'points',
#  'blundered',
#  'foreplanned',
#  'answering',
#  'wettest',
#  'concessions',
#  'delaford',
#  'affording',
#  'holds',
#  'willoughby',
#  'livings',
#  'cheated',
#  'simpered',
#  'duties',
#  'dismissed',
#  'terms',
#  'garrets',
#  'patronised',
#  'asked',
#  'alienated',
#  'blushes',
#  'deeper',
#  'missed',
#  'showed',
#  'humiliations',
#  'weddings',
#  'imagining',
#  'supplanted',
#  'mothers',
#  'overstrained',
#  'services',
#  'letting',
#  'thirds',
#  'trifled',
#  'performing',
#  'hopes',
#  'danced',
#  'differed',
#  'knives',
#  'passions',
#  'ii',
#  'says',
#  'subsisted',
#  'lengths',
#  'foreseen',
#  'grows',
#  'packages',
#  'supplying',
#  'attracted',
#  'houses',
#  'happens',
#  'insisted',
#  'casts',
#  'rooms',
#  'remembers',
#  'insinuations',
# ...

# %%
list01 = {'1','2','a','b','d','what'}

# %%
list02 = {'a'}

# %%
list01 - list02
# Out:
# {'1', '2', 'b', 'd', 'what'}

# %%
unusual_words({'1','2','a','b','d','what','Ericsson'})
# Out:
# {'ericsson'}

# %%
unusual_words(nltk.corpus.nps_chat.words())
# Out:
# {'canadaian',
#  'farting',
#  'elected',
#  'jackie',
#  'dryer',
#  'syck',
#  'ridem',
#  'prittier',
#  'losted',
#  'messaging',
#  'niceeee',
#  'holds',
#  'baaaaalllllllliiiiiiinnnnnnnnnnn',
#  'macho',
#  'facilitated',
#  'asked',
#  'deleware',
#  'extras',
#  'deeper',
#  'moped',
#  'beattles',
#  'outa',
#  'ooo',
#  'innit',
#  'bulls',
#  'invisiable',
#  'missin',
#  'roleplay',
#  'gguyyyzzzz',
#  'muzak',
#  'ep',
#  'sox',
#  'goths',
#  'outs',
#  'controllin',
#  'chatr',
#  'fart',
#  'cpr',
#  'attracted',
#  'mothas',
#  'hawt',
#  'quizes',
#  'casts',
#  'beachhhh',
#  'fellows',
#  'poeple',
#  'paitently',
#  'jumpin',
#  'knuckles',
#  'mami',
#  'smacked',
#  'pounces',
#  'heyy',
#  'dya',
#  'intersting',
#  'kool',
#  'mena',
#  'wel',
#  'sweats',
#  'ntmn',
#  'tc',
#  'douchebag',
#  'lmaoo',
#  'guyzz',
#  'immersed',
#  'stretches',
#  'thinkin',
#  'oppertunity',
#  'sp',
#  'ct',
#  'clinicals',
#  'changed',
#  'moans',
#  'elbows',
# ...

# %%
def content_fration (text):
    stopwords = nltk.corpus.stopwords.words('english')
    content = [w for w in text if w.lower() not in stopwords]
    return len(content)/len(text)

# %%
content_fration(wordlist.words('Trace_sample.txt'))
# Out:
# 0.9983007646559049

# %%
trace_txt = wordlist.words('Trace_sample.txt')

# %% [markdown]
# # 5 WordNet

# %%
import nltk
from nltk.corpus import wordnet as wn

# %%
wn.synsets('car')
# Out:
# [Synset('car.n.01'),
#  Synset('car.n.02'),
#  Synset('car.n.03'),
#  Synset('car.n.04'),
#  Synset('cable_car.n.01')]

# %%
wn.synset('car.n.02').lemma_names()
# Out:
# ['car', 'railcar', 'railway_car', 'railroad_car']

# %%
wn.synset('car.n.02').definition()
# Out:
# 'a wheeled vehicle adapted to the rails of railroad'

# %%
wn.synset('car.n.02').lemmas()
# Out:
# [Lemma('car.n.02.car'),
#  Lemma('car.n.02.railcar'),
#  Lemma('car.n.02.railway_car'),
#  Lemma('car.n.02.railroad_car')]

# %%
wn.synset('car.n.02').examples()
# Out:
# ['three cars had jumped the rails']

# %%
for synset in wn.synsets('car'):
    print (synset.lemma_names())
# Out:
# ['car', 'auto', 'automobile', 'machine', 'motorcar']
# ['car', 'railcar', 'railway_car', 'railroad_car']
# ['car', 'gondola']
# ['car', 'elevator_car']
# ['cable_car', 'car']

# %%
motorcar = wn.synset('car.n.01')

# %%
types_of_motorcar = motorcar.hyponyms()

# %%
types_of_motorcar
# Out:
# [Synset('ambulance.n.01'),
#  Synset('beach_wagon.n.01'),
#  Synset('bus.n.04'),
#  Synset('cab.n.03'),
#  Synset('compact.n.03'),
#  Synset('convertible.n.01'),
#  Synset('coupe.n.01'),
#  Synset('cruiser.n.01'),
#  Synset('electric.n.01'),
#  Synset('gas_guzzler.n.01'),
#  Synset('hardtop.n.01'),
#  Synset('hatchback.n.01'),
#  Synset('horseless_carriage.n.01'),
#  Synset('hot_rod.n.01'),
#  Synset('jeep.n.01'),
#  Synset('limousine.n.01'),
#  Synset('loaner.n.02'),
#  Synset('minicar.n.01'),
#  Synset('minivan.n.01'),
#  Synset('model_t.n.01'),
#  Synset('pace_car.n.01'),
#  Synset('racer.n.02'),
#  Synset('roadster.n.01'),
#  Synset('sedan.n.01'),
#  Synset('sport_utility.n.01'),
#  Synset('sports_car.n.01'),
#  Synset('stanley_steamer.n.01'),
#  Synset('stock_car.n.01'),
#  Synset('subcompact.n.01'),
#  Synset('touring_car.n.01'),
#  Synset('used-car.n.01')]

# %%
sorted(lemma.name() for synset in types_of_motorcar for lemma in synset.lemmas())
# Out:
# ['Model_T',
#  'S.U.V.',
#  'SUV',
#  'Stanley_Steamer',
#  'ambulance',
#  'beach_waggon',
#  'beach_wagon',
#  'bus',
#  'cab',
#  'compact',
#  'compact_car',
#  'convertible',
#  'coupe',
#  'cruiser',
#  'electric',
#  'electric_automobile',
#  'electric_car',
#  'estate_car',
#  'gas_guzzler',
#  'hack',
#  'hardtop',
#  'hatchback',
#  'heap',
#  'horseless_carriage',
#  'hot-rod',
#  'hot_rod',
#  'jalopy',
#  'jeep',
#  'landrover',
#  'limo',
#  'limousine',
#  'loaner',
#  'minicar',
#  'minivan',
#  'pace_car',
#  'patrol_car',
#  'phaeton',
#  'police_car',
#  'police_cruiser',
#  'prowl_car',
#  'race_car',
#  'racer',
#  'racing_car',
#  'roadster',
#  'runabout',
#  'saloon',
#  'secondhand_car',
#  'sedan',
#  'sport_car',
#  'sport_utility',
#  'sport_utility_vehicle',
#  'sports_car',
#  'squad_car',
#  'station_waggon',
#  'station_wagon',
#  'stock_car',
#  'subcompact',
#  'subcompact_car',
#  'taxi',
#  'taxicab',
#  'tourer',
#  'touring_car',
# ...

# %%
motorcar.hypernyms()
# Out:
# [Synset('motor_vehicle.n.01')]

# %%
motorcar.root_hypernyms()
# Out:
# [Synset('entity.n.01')]

# %% [markdown]
# ## 5.3 More Lexical Relations

# %%
wn.synset('tree.n.01').part_meronyms()
# Out:
# [Synset('burl.n.02'),
#  Synset('crown.n.07'),
#  Synset('limb.n.02'),
#  Synset('stump.n.01'),
#  Synset('trunk.n.01')]

# %%
wn.synset('tree.n.01').substance_meronyms()
# Out:
# [Synset('heartwood.n.01'), Synset('sapwood.n.01')]

# %%
wn.synset('tree.n.01').member_holonyms()
# Out:
# [Synset('forest.n.01')]

# %% [markdown]
# ## 5.4 Sematic Similarity
